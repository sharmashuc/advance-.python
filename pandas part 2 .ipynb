# %% [markdown]
# # EDA ==> Exploratory Data Analysis

# %% [markdown]
# # parts of eda

# %% [markdown]
# # 1. univariate analysis===> analysis on a single independent column
# #2. bivariate analysis ==> analysis on two columns
# #3. multivariate analysis ==> analysis on more than 2 columns

# %%
# data types 
# 1. numerical data ===> continous data===> age(year,month,days),height,weight,etc.
#2. categorical data===> descrete data==> total number of employess

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt #visualiztion  ibrary
import seaborn as sns # matplotib's updated version is seaborn.

# %%
df=pd.read_csv("C:\\Users\\snehr\\Desktop\\Datasets for pandas (24-05-2024)_files\\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # 1. univariate analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# if we want to see acutal values then we use value_counts().
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
#if we want to check for Pclass then

sns.countplot(x= df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
# if we want to find out percentage then use
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
# if we have numerical data then we use histogram
# because if finds the distribution

# %%
plt.hist(x=df['Age'])
# Out:
# (array([16., 16., 71., 97., 43., 37., 25., 17.,  9.,  1.]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]),
#  <BarContainer object of 10 artists>)

# %%
# 2.Distplot
# curve==> KDE(kernal density extraction)
# use for find probabilty

# %%
sns.distplot(x= df['Age'])
# Out:
# C:\Users\snehr\AppData\Local\Temp\ipykernel_16416\1276333823.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x= df['Age'])
# C:\Users\snehr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.distplot(df['Age'] , hist = False)
# Out:
# C:\Users\snehr\AppData\Local\Temp\ipykernel_16416\2560391799.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'] , hist = False)
# C:\Users\snehr\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Age', ylabel='Density'>

# %%
# 3. Boxplot
# for find our outliers

# 1. lower fence
# 2. 25% data
# 3. IQR (inter quartile range )(75%-25%)
# 4. 75% data
# 5. upper fence

# %%
sns. boxplot(x = df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
tips =pd.read_csv("C:\\Users\\snehr\\Desktop\\Datasets for pandas (24-05-2024)_files\\tips.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # biveriate analysis
# # 1. scatterplot(numerical column - numerical column)

# %%
sns.scatterplot(x = tips['total_bill'] , #df['total_bill']
                 y = tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips , hue = tips['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill" ,
                y="tip" , data = tips ,
                hue = tips['sex'] , style = tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df=pd.read_csv("C:\\Users\\snehr\\Desktop\\Datasets for pandas (24-05-2024)_files\\titanic.csv")

# %%
# heatmap(categorical-categorical)
p = pd.crosstab(df['Pclass'] , df['Survived'])
p
# Out:
# Survived    0   1
# Pclass
# 1          57  50
# 2          63  30
# 3         146  72

# %%
sns.heatmap(p)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df = df.drop(columns = ['Name' , 'Sex' , 'SibSp' , 'Parch' , 'Ticket' , 'Cabin' , 'Embarked'])

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass   Age    Fare
# 0          892         0       3  34.5  7.8292
# 1          893         1       3  47.0  7.0000

# %%
df = df.dropna()

# %%
((df.groupby('Pclass').mean()['Survived'])*100).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Pclass'>
